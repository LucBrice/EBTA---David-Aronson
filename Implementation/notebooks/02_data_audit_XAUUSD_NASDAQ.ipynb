# %% [markdown]
# # Data Audit XAUUSD NASDAQ

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

# %%
from ebta_engine.data.local_ohlcv import DEFAULT_DATA_ROOT, build_data_snapshot
build_data_snapshot(DEFAULT_DATA_ROOT, ['NASDAQ', 'XAUUSD'], start='2020-01-01T00:00:00Z', end='2020-01-03T23:59:00Z')
