# %% [markdown]
# # EBTA Native MVP Preflight

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

# %%
from pathlib import Path
from ebta_engine.package_builder.native_research_package import DEFAULT_MVP_ASSETS, DEFAULT_MVP_START, DEFAULT_MVP_END
DEFAULT_MVP_ASSETS, DEFAULT_MVP_START, DEFAULT_MVP_END
