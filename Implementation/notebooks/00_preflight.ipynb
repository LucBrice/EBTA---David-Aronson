# %% [markdown]
# # EBTA Nautilus MVP Preflight

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

# %%
from pathlib import Path
from ebta_engine.package_builder.nautilus_research_package import DEFAULT_NAUTILUS_ASSETS, DEFAULT_NAUTILUS_START, DEFAULT_NAUTILUS_END
DEFAULT_NAUTILUS_ASSETS, DEFAULT_NAUTILUS_START, DEFAULT_NAUTILUS_END
