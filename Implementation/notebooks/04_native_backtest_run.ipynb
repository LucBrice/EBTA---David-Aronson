# %% [markdown]
# # Nautilus Backtest Run

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

# %%
from ebta_engine.package_builder.nautilus_research_package import build_nautilus_research_package
from pathlib import Path
package_dir = Path('../research_packages/nautilus_mvp')
build_nautilus_research_package(package_dir)
